# %% [markdown]
# # M&M ASH benchmark V
#
# This is a continuation of Part V where I set total PVE is set to 0.15 and assume 2 causal variables per region. But here, the two SNPs have the same effects sampled from the multivariate distribution. Also I use $R = 5$ conditions and run it on $J=1000$ and 150 genes.
#
# The most important difference from previous simulations is that here I mix-match simulated data under different prior assumptions to analyzing them with different priors. I expect to observe that:
#
# 1. The "oracle" prior is always better than using other priors, for all scenarios.
# 2. Mixture prior generally performs well in all scenarios -- it is robust to simulation assumptions.

# %% [markdown]
# ## Conclusion
#
# ...

# %% [markdown]
# The benchmark was executd on UChicago midway
#
# ```
# ./finemap.dsc --host mnm_R5.yml
# ```
#
# This executes the `default` pipeline in `finemap.dsc` file, as of today (2019.02.04).
#
# TOFIX:
# 1. use larger trunks for scores
# 2. use more R
# 3.

# %%
%cd ~/GIT/github/mnm-twas/dsc
# Out:
# /scratch/midway2/gaow/GIT/github/mnm-twas/dsc

# %%
start_time <- Sys.time()
library('dscrutils')
out = dscquery('finemap_output', "small_data.dataset sharing_pattern.n_signal mnm.eff_mode susie_scores.total susie_scores.valid susie_scores.size susie_scores.purity susie_scores.top")
end_time <- Sys.time()
# Out:
# Loading dsc-query output from CSV file.
# Reading DSC outputs:
#  - sharing_pattern.n_signal: extracted atomic values
#  - susie_scores.total: extracted atomic values
#  - susie_scores.valid: extracted atomic values
#  - susie_scores.size: extracted atomic values
#  - susie_scores.purity: extracted atomic values
#  - susie_scores.top: extracted atomic values

# %%
end_time - start_time
# Out:
# Time difference of 3.511436 mins

# %%
head(out)
# Out:
#   DSC small_data.dataset                                  sharing_pattern
# 1 1   ~/Documents/GTExV8/Thyroid.Lung.FMO2.filled.rds     identity
# 2 1   ~/Documents/GTExV8/Toys/Thyroid.ENSG00000031823.RDS identity
# 3 1   ~/Documents/GTExV8/Toys/Thyroid.ENSG00000062194.RDS identity
# 4 1   ~/Documents/GTExV8/Toys/Thyroid.ENSG00000073150.RDS identity
# 5 1   ~/Documents/GTExV8/Toys/Thyroid.ENSG00000078319.RDS identity
# 6 1   ~/Documents/GTExV8/Toys/Thyroid.ENSG00000081277.RDS identity
#   sharing_pattern.n_signal mnm          mnm.eff_mode susie_scores.total
# 1 2                        mnm_identity identity     2
# 2 2                        mnm_identity identity     2
# 3 2                        mnm_identity identity     2
# 4 2                        mnm_identity identity     2
# 5 2                        mnm_identity identity     2
# 6 2                        mnm_identity identity     2
#   susie_scores.valid susie_scores.size susie_scores.purity susie_scores.top
# 1 2                  15.0              0.9903631           2
# 2 2                   3.0              0.9881356           2
# 3 2                   2.5              0.9154794           0
# 4 2                  11.5              0.9847950           1
# 5 2                   1.0              1.0000000           2
# 6 2                   3.5              0.9898003           1

# %%
res = out[,c(3,4,6,7,8,9,10,11)]
colnames(res) = c('pattern', 'total_true', 'method', 'total', 'valid', 'size', 'purity', 'top_hit')

# %% [markdown]
# ### Purity of CS

# %%
aggregate(purity~pattern + method, res, mean)
# Out:
#    pattern   method    purity
# 1  high_het  high_het  0.9763817
# 2  identity  high_het  0.9813603
# 3  low_het   high_het  0.9783048
# 4  mid_het   high_het  0.9770469
# 5  mixture01 high_het  0.9697439
# 6  shared    high_het  0.9780834
# 7  singleton high_het  0.9304426
# 8  high_het  identity  0.9766740
# 9  identity  identity  0.9818320
# 10 low_het   identity  0.9793122
# 11 mid_het   identity  0.9771917
# 12 mixture01 identity  0.9698374
# 13 shared    identity  0.9758949
# 14 singleton identity  0.9313651
# 15 high_het  low_het   0.9769505
# 16 identity  low_het   0.9826347
# 17 low_het   low_het   0.9792410
# 18 mid_het   low_het   0.9755808
# 19 mixture01 low_het   0.9676163
# 20 shared    low_het   0.9754983
# 21 singleton low_het   0.9287453
# 22 high_het  mid_het   0.9765622
# 23 identity  mid_het   0.9820084
# 24 low_het   mid_het   0.9785862
# 25 mid_het   mid_het   0.9772789
# 26 mixture01 mid_het   0.9690584
# 27 shared    mid_het   0.9760828
# 28 singleton mid_het   0.9292686
# 29 high_het  mixture_1 0.9838106
# 30 identity  mixture_1 0.9836787
# 31 low_het   mixture_1 0.9805234
# 32 mid_het   mixture_1 0.9788453
# 33 mixture01 mixture_1 0.9700957
# 34 shared    mixture_1 0.9783411
# 35 singleton mixture_1 0.9320027
# 36 high_het  shared    0.7528230
# 37 identity  shared    0.7003914
# 38 low_het   shared    0.8455371
# 39 mid_het   shared    0.7673202
# 40 mixture01 shared    0.7116157
# 41 shared    shared    0.9765241
# 42 singleton shared    0.1766352
# 43 high_het  singleton 0.9310388
# 44 identity  singleton 0.9302134
# 45 low_het   singleton 0.9255558
# 46 mid_het   singleton 0.9295267
# 47 mixture01 singleton 0.9221725
# 48 shared    singleton 0.9135379
# 49 singleton singleton 0.9296731

# %% [markdown]
# ### Size of CS

# %%
aggregate(size~pattern+method, res, median)
# Out:
#    pattern   method    size
# 1  high_het  high_het   3.50
# 2  identity  high_het   4.00
# 3  low_het   high_het   4.50
# 4  mid_het   high_het   4.00
# 5  mixture01 high_het   5.00
# 6  shared    high_het   3.25
# 7  singleton high_het   7.00
# 8  high_het  identity   3.50
# 9  identity  identity   4.00
# 10 low_het   identity   4.50
# 11 mid_het   identity   4.00
# 12 mixture01 identity   5.00
# 13 shared    identity   3.25
# 14 singleton identity   7.00
# 15 high_het  low_het    3.50
# 16 identity  low_het    4.00
# 17 low_het   low_het    4.50
# 18 mid_het   low_het    4.00
# 19 mixture01 low_het    5.00
# 20 shared    low_het    3.25
# 21 singleton low_het    7.50
# 22 high_het  mid_het    3.50
# 23 identity  mid_het    4.00
# 24 low_het   mid_het    4.50
# 25 mid_het   mid_het    4.00
# 26 mixture01 mid_het    5.00
# 27 shared    mid_het    3.25
# 28 singleton mid_het    7.00
# 29 high_het  mixture_1  3.00
# 30 identity  mixture_1  4.00
# 31 low_het   mixture_1  4.50
# 32 mid_het   mixture_1  4.00
# 33 mixture01 mixture_1  4.75
# 34 shared    mixture_1  3.25
# 35 singleton mixture_1  8.00
# 36 high_het  shared     3.75
# 37 identity  shared     6.00
# 38 low_het   shared     5.50
# 39 mid_het   shared     4.25
# 40 mixture01 shared     3.50
# 41 shared    shared     3.50
# 42 singleton shared     0.00
# 43 high_het  singleton  8.00
# 44 identity  singleton 11.00
# 45 low_het   singleton 10.00
# 46 mid_het   singleton  9.00
# 47 mixture01 singleton  9.00
# 48 shared    singleton  9.75
# 49 singleton singleton  8.00

# %% [markdown]
# ### Power

# %%
valid = aggregate(valid ~ pattern + method, res, sum)
total_true = aggregate(total_true ~ pattern + method, res, sum)
power = merge(valid, total_true, by = c("pattern", "method"))
power$power = power$valid/power$total_true
power
# Out:
#    pattern   method    valid total_true power
# 1  high_het  high_het  264   300        0.8800000
# 2  high_het  identity  264   300        0.8800000
# 3  high_het  low_het   260   300        0.8666667
# 4  high_het  mid_het   263   300        0.8766667
# 5  high_het  mixture_1 248   300        0.8266667
# 6  high_het  shared    176   300        0.5866667
# 7  high_het  singleton 705   300        2.3500000
# 8  identity  high_het  283   300        0.9433333
# 9  identity  identity  282   300        0.9400000
# 10 identity  low_het   280   300        0.9333333
# 11 identity  mid_het   282   300        0.9400000
# 12 identity  mixture_1 266   300        0.8866667
# 13 identity  shared    164   300        0.5466667
# 14 identity  singleton 786   300        2.6200000
# 15 low_het   high_het  277   300        0.9233333
# 16 low_het   identity  276   300        0.9200000
# 17 low_het   low_het   275   300        0.9166667
# 18 low_het   mid_het   276   300        0.9200000
# 19 low_het   mixture_1 257   300        0.8566667
# 20 low_het   shared    218   300        0.7266667
# 21 low_het   singleton 754   300        2.5133333
# 22 mid_het   high_het  274   300        0.9133333
# 23 mid_het   identity  274   300        0.9133333
# 24 mid_het   low_het   275   300        0.9166667
# 25 mid_het   mid_het   274   300        0.9133333
# 26 mid_het   mixture_1 251   300        0.8366667
# 27 mid_het   shared    186   300        0.6200000
# 28 mid_het   singleton 770   300        2.5666667
# 29 mixture01 high_het  244   300        0.8133333
# 30 mixture01 identity  244   300        0.8133333
# 31 mixture01 low_het   243   300        0.8100000
# 32 mixture01 mid_het   243   300        0.8100000
# 33 mixture01 mixture_1 235   300        0.7833333
# 34 mixture01 shared    179   300        0.5966667
# 35 mixture01 singleton 629   300        2.0966667
# 36 shared    high_het  263   300        0.8766667
# 37 shared    identity  263   300        0.8766667
# 38 shared    low_het   265   300        0.8833333
# 39 shared    mid_het   264   300        0.8800000
# 40 shared    mixture_1 258   300        0.8600000
# 41 shared    shared    260   300        0.8666667
# 42 shared    singleton 756   300        2.5200000
# 43 singleton high_het  211   300        0.7033333
# 44 singleton identity  210   300        0.7000000
# 45 singleton low_het   211   300        0.7033333
# 46 singleton mid_het   211   300        0.7033333
# 47 singleton mixture_1 196   300        0.6533333
# 48 singleton shared     30   300        0.1000000
# 49 singleton singleton 199   300        0.6633333

# %% [markdown]
# ### FDR

# %%
valid = aggregate(valid ~ pattern + method, res, sum)
total = aggregate(total ~ pattern + method, res, sum)
fdr = merge(valid, total, by = c("pattern", "method"))
fdr$fdr = (fdr$total - fdr$valid)/fdr$total
fdr
# Out:
#    pattern   method    valid total fdr
# 1  high_het  high_het  264   293   0.09897611
# 2  high_het  identity  264   292   0.09589041
# 3  high_het  low_het   260   288   0.09722222
# 4  high_het  mid_het   263   291   0.09621993
# 5  high_het  mixture_1 248   267   0.07116105
# 6  high_het  shared    176   187   0.05882353
# 7  high_het  singleton 705   757   0.06869221
# 8  identity  high_het  283   308   0.08116883
# 9  identity  identity  282   307   0.08143322
# 10 identity  low_het   280   303   0.07590759
# 11 identity  mid_het   282   307   0.08143322
# 12 identity  mixture_1 266   280   0.05000000
# 13 identity  shared    164   172   0.04651163
# 14 identity  singleton 786   851   0.07638073
# 15 low_het   high_het  277   299   0.07357860
# 16 low_het   identity  276   298   0.07382550
# 17 low_het   low_het   275   297   0.07407407
# 18 low_het   mid_het   276   298   0.07382550
# 19 low_het   mixture_1 257   266   0.03383459
# 20 low_het   shared    218   224   0.02678571
# 21 low_het   singleton 754   786   0.04071247
# 22 mid_het   high_het  274   297   0.07744108
# 23 mid_het   identity  274   297   0.07744108
# 24 mid_het   low_het   275   295   0.06779661
# 25 mid_het   mid_het   274   297   0.07744108
# 26 mid_het   mixture_1 251   268   0.06343284
# 27 mid_het   shared    186   195   0.04615385
# 28 mid_het   singleton 770   821   0.06211937
# 29 mixture01 high_het  244   278   0.12230216
# 30 mixture01 identity  244   280   0.12857143
# 31 mixture01 low_het   243   277   0.12274368
# 32 mixture01 mid_het   243   277   0.12274368
# 33 mixture01 mixture_1 235   247   0.04858300
# 34 mixture01 shared    179   186   0.03763441
# 35 mixture01 singleton 629   663   0.05128205
# 36 shared    high_het  263   298   0.11744966
# 37 shared    identity  263   298   0.11744966
# 38 shared    low_het   265   300   0.11666667
# 39 shared    mid_het   264   300   0.12000000
# 40 shared    mixture_1 258   288   0.10416667
# 41 shared    shared    260   291   0.10652921
# 42 shared    singleton 756   819   0.07692308
# 43 singleton high_het  211   233   0.09442060
# 44 singleton identity  210   233   0.09871245
# 45 singleton low_het   211   232   0.09051724
# 46 singleton mid_het   211   233   0.09442060
# 47 singleton mixture_1 196   207   0.05314010
# 48 singleton shared     30    33   0.09090909
# 49 singleton singleton 199   210   0.05238095

# %% [markdown]
# ### Top-hit rate (how often the strongest SNP is causal)

# %%
top_hit = aggregate(top_hit ~ pattern + method, res, sum)
total_true = aggregate(total_true ~ pattern + method, res, sum)
top_rate = merge(top_hit, total_true, by = c("pattern", "method"))
top_rate$top_rate = top_rate$top_hit/top_rate$total_true
top_rate
# Out:
#    pattern   method    top_hit total_true top_rate
# 1  high_het  high_het  174     300        0.58000000
# 2  high_het  identity  174     300        0.58000000
# 3  high_het  low_het   171     300        0.57000000
# 4  high_het  mid_het   172     300        0.57333333
# 5  high_het  mixture_1 164     300        0.54666667
# 6  high_het  shared     99     300        0.33000000
# 7  high_het  singleton 404     300        1.34666667
# 8  identity  high_het  174     300        0.58000000
# 9  identity  identity  174     300        0.58000000
# 10 identity  low_het   174     300        0.58000000
# 11 identity  mid_het   174     300        0.58000000
# 12 identity  mixture_1 167     300        0.55666667
# 13 identity  shared     71     300        0.23666667
# 14 identity  singleton 359     300        1.19666667
# 15 low_het   high_het  167     300        0.55666667
# 16 low_het   identity  166     300        0.55333333
# 17 low_het   low_het   167     300        0.55666667
# 18 low_het   mid_het   167     300        0.55666667
# 19 low_het   mixture_1 155     300        0.51666667
# 20 low_het   shared    109     300        0.36333333
# 21 low_het   singleton 380     300        1.26666667
# 22 mid_het   high_het  167     300        0.55666667
# 23 mid_het   identity  167     300        0.55666667
# 24 mid_het   low_het   169     300        0.56333333
# 25 mid_het   mid_het   167     300        0.55666667
# 26 mid_het   mixture_1 158     300        0.52666667
# 27 mid_het   shared     97     300        0.32333333
# 28 mid_het   singleton 456     300        1.52000000
# 29 mixture01 high_het  144     300        0.48000000
# 30 mixture01 identity  144     300        0.48000000
# 31 mixture01 low_het   145     300        0.48333333
# 32 mixture01 mid_het   143     300        0.47666667
# 33 mixture01 mixture_1 144     300        0.48000000
# 34 mixture01 shared    107     300        0.35666667
# 35 mixture01 singleton 342     300        1.14000000
# 36 shared    high_het  158     300        0.52666667
# 37 shared    identity  158     300        0.52666667
# 38 shared    low_het   159     300        0.53000000
# 39 shared    mid_het   158     300        0.52666667
# 40 shared    mixture_1 159     300        0.53000000
# 41 shared    shared    158     300        0.52666667
# 42 shared    singleton 382     300        1.27333333
# 43 singleton high_het   94     300        0.31333333
# 44 singleton identity   93     300        0.31000000
# 45 singleton low_het    93     300        0.31000000
# 46 singleton mid_het    93     300        0.31000000
# 47 singleton mixture_1  85     300        0.28333333
# 48 singleton shared      8     300        0.02666667
# 49 singleton singleton  87     300        0.29000000

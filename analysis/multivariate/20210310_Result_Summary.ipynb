# %% [markdown]
# ## mvSuSiE benchmark results summary
#
# Commands generated the results in this notebook [can be found here](20210224_MNM_Benchmark.html).

# %% [markdown]
# ## Credible sets

# %% [markdown]
# ### Without missing data

# %%
%cd /home/gaow/GIT/mvarbvs/dsc/mnm_prototype/mnm_20210310
# Out:
# /project2/mstephens/gaow/mvarbvs/dsc/mnm_prototype/mnm_20210310

# %%
readRDS("mnm_20210310.cs_summary.rds")$table
# Out:
#    simulate           method                       total overlap_cs size
# 9  artificial_mixture mnm_shared+flash_residual     431   0         6.75
# 10 artificial_mixture mnm_shared+oracle_residual    455   0         6.00
# 3  artificial_mixture mnm_identity+flash_residual   704   0         5.00
# 4  artificial_mixture mnm_identity+oracle_residual  728   0         4.50
# 1  artificial_mixture mnm_ed+flash_residual         720   0         5.00
# 2  artificial_mixture mnm_ed+oracle_residual        734   0         4.00
# 5  artificial_mixture mnm_naive+flash_residual      814  42         5.00
# 6  artificial_mixture mnm_naive+oracle_residual     833  42         5.00
# 7  artificial_mixture mnm_oracle+flash_residual     836   4         5.50
# 8  artificial_mixture mnm_oracle+oracle_residual    849   3         5.00
# 19 gtex_mixture       mnm_shared+flash_residual     727   0         7.00
# 20 gtex_mixture       mnm_shared+oracle_residual    791   1         6.00
# ...

# %% [markdown]
# ### With missing data

# %%
%cd /home/gaow/GIT/mvarbvs/dsc/mnm_prototype/mnm_missing_20210310
# Out:
# /project2/mstephens/gaow/mvarbvs/dsc/mnm_prototype/mnm_missing_20210310

# %%
readRDS("mnm_missing_20210310.cs_summary.rds")$table
# Out:
#    simulate_missing           method                       total overlap_cs
# 9  artificial_mixture_missing mnm_shared+flash_residual    362    0
# 10 artificial_mixture_missing mnm_shared+oracle_residual   376    0
# 3  artificial_mixture_missing mnm_identity+flash_residual  525    0
# 4  artificial_mixture_missing mnm_identity+oracle_residual 540    0
# 1  artificial_mixture_missing mnm_ed+flash_residual        566    0
# 5  artificial_mixture_missing mnm_naive+flash_residual     577    9
# 2  artificial_mixture_missing mnm_ed+oracle_residual       583    0
# 6  artificial_mixture_missing mnm_naive+oracle_residual    596   12
# 7  artificial_mixture_missing mnm_oracle+flash_residual    634    0
# 8  artificial_mixture_missing mnm_oracle+oracle_residual   640    0
# 13 gtex_mixture_missing       mnm_identity+flash_residual  559    0
# 19 gtex_mixture_missing       mnm_shared+flash_residual    596    1
# 20 gtex_mixture_missing       mnm_shared+oracle_residual   615    1
# ...

# %% [markdown]
# ## PIPs

# %%
%cd /home/gaow/GIT/mvarbvs/dsc/mnm_prototype/mnm_20210310
# Out:
# /project2/mstephens/gaow/mvarbvs/dsc/mnm_prototype/mnm_20210310

# %% [markdown]
# ### Calibration (condition specific)

# %%
%preview mnm_20210310.artificial_mixture.pip_condition.calibration.png
# Out:
# > mnm_20210310.artificial_mixture.pip_condition.calibration.png (86.4 KiB):

# %%
%preview mnm_20210310.gtex_mixture.pip_condition.calibration.png
# Out:
# > mnm_20210310.gtex_mixture.pip_condition.calibration.png (85.6 KiB):

# %% [markdown]
# ### Calibration (global)

# %%
%preview mnm_20210310.artificial_mixture.pip_global.calibration.png
# Out:
# > mnm_20210310.artificial_mixture.pip_global.calibration.png (93.0 KiB):

# %%
%preview mnm_20210310.gtex_mixture.pip_global.calibration.png
# Out:
# > mnm_20210310.gtex_mixture.pip_global.calibration.png (93.0 KiB):

# %% [markdown]
# ### ROC (condition specific)

# %%
%preview mnm_20210310.artificial_mixture.pip_condition.curves.roc.pdf -s png
# Out:
# > mnm_20210310.artificial_mixture.pip_condition.curves.roc.pdf (52.6 KiB):

# %%
%preview mnm_20210310.gtex_mixture.pip_condition.curves.roc.pdf -s png
# Out:
# > mnm_20210310.gtex_mixture.pip_condition.curves.roc.pdf (53.0 KiB):

# %% [markdown]
# ### ROC (global)

# %%
%preview mnm_20210310.artificial_mixture.pip_global.curves.roc.pdf -s png
# Out:
# > mnm_20210310.artificial_mixture.pip_global.curves.roc.pdf (28.1 KiB):

# %%
%preview mnm_20210310.gtex_mixture.pip_global.curves.roc.pdf -s png
# Out:
# > mnm_20210310.gtex_mixture.pip_global.curves.roc.pdf (30.8 KiB):

# %% [markdown]
# # M&M ASH benchmark V
#
# This is a continuation of Part V where I set total PVE is set to 0.15 and assume 2 causal variables per region. But here, the two SNPs have the same effects sampled from the multivariate distribution. Also I use $R = 5$ conditions and run it on $J=1000$ and 150 genes.
#
# The most important difference from previous simulations is that here I mix-match simulated data under different prior assumptions to analyzing them with different priors. I expect to observe that:
#
# 1. The "oracle" prior is always better than using other priors, for all scenarios.
# 2. Mixture prior generally performs well in all scenarios -- it is robust to simulation assumptions.

# %% [markdown]
# ## Conclusion
#
# ...

# %% [markdown]
# The benchmark was executd on UChicago midway
#
# ```
# ./finemap.dsc --host mnm_R5.yml --R 5
# ```
#
# This executes the `default` pipeline in `finemap.dsc` file, as of today (2019.02.04).

# %%
%cd ~/GIT/github/mnm-twas/dsc
# Out:
# /scratch/midway2/gaow/GIT/github/mnm-twas/dsc

# %%
start_time <- Sys.time()
library('dscrutils')
out = dscquery('finemap_output', "sharing_pattern mnm.eff_mode susie_scores.total susie_scores.valid susie_scores.size susie_scores.purity susie_scores.top susie_scores.n_causal susie_scores.overlap", omit.file.columns = T)
end_time <- Sys.time()
# Out:
# Loading dsc-query output from CSV file.
# Reading DSC outputs:
#  - susie_scores.total: extracted atomic values
#  - susie_scores.valid: extracted atomic values
#  - susie_scores.size: extracted atomic values
#  - susie_scores.purity: extracted atomic values
#  - susie_scores.top: extracted atomic values
#  - susie_scores.n_causal: extracted atomic values
#  - susie_scores.overlap: extracted atomic values

# %%
end_time - start_time
# Out:
# Time difference of 2.014167 mins

# %%
head(out)
# Out:
#   DSC sharing_pattern mnm          mnm.eff_mode susie_scores.total
# 1 1   identity        mnm_identity identity     2
# 2 1   identity        mnm_identity identity     1
# 3 1   identity        mnm_identity identity     1
# 4 1   identity        mnm_identity identity     1
# 5 1   identity        mnm_identity identity     1
# 6 1   identity        mnm_identity identity     1
#   susie_scores.valid susie_scores.size susie_scores.purity susie_scores.top
# 1 2                   3.5              1.0000000           1
# 2 1                   1.0              1.0000000           1
# 3 1                   9.0              0.9886828           0
# 4 1                  10.0              1.0000000           0
# 5 1                  13.0              0.9875783           0
# 6 1                   4.0              0.9960325           0
#   susie_scores.n_causal susie_scores.overlap
# 1 2                     0
# 2 1                     0
# 3 1                     0
# 4 1                     0
# 5 1                     0
# 6 1                     0

# %%
res = out[,c(2,4,5,6,7,8,9,10,11)]
colnames(res) = c('pattern', 'method', 'total', 'valid', 'size', 'purity', 'top_hit', 'total_true', 'overlap')

# %% [markdown]
# ### Purity of CS

# %%
aggregate(purity~pattern + method, res, mean)
# Out:
#    pattern   method    purity
# 1  high_het  high_het  0.9916862
# 2  identity  high_het  0.9917146
# 3  low_het   high_het  0.9884244
# 4  mid_het   high_het  0.9923806
# 5  mixture01 high_het  0.9757964
# 6  shared    high_het  0.9904957
# 7  singleton high_het  0.9241387
# 8  high_het  identity  0.9913949
# 9  identity  identity  0.9917000
# 10 low_het   identity  0.9886923
# 11 mid_het   identity  0.9919891
# 12 mixture01 identity  0.9769534
# 13 shared    identity  0.9904997
# 14 singleton identity  0.9229322
# 15 high_het  low_het   0.9917899
# 16 identity  low_het   0.9921787
# 17 low_het   low_het   0.9918518
# 18 mid_het   low_het   0.9924335
# 19 mixture01 low_het   0.9739553
# 20 shared    low_het   0.9902886
# 21 singleton low_het   0.9205336
# 22 high_het  mid_het   0.9916245
# 23 identity  mid_het   0.9924849
# 24 low_het   mid_het   0.9897733
# 25 mid_het   mid_het   0.9923608
# 26 mixture01 mid_het   0.9741854
# 27 shared    mid_het   0.9903303
# 28 singleton mid_het   0.9208219
# 29 high_het  mixture_1 0.9861684
# 30 identity  mixture_1 0.9922034
# 31 low_het   mixture_1 0.9912703
# 32 mid_het   mixture_1 0.9920922
# 33 mixture01 mixture_1 0.9803773
# 34 shared    mixture_1 0.9911939
# 35 singleton mixture_1 0.9369633
# 36 high_het  shared    0.9152451
# 37 identity  shared    0.9340737
# 38 low_het   shared    0.9732253
# 39 mid_het   shared    0.9395782
# 40 mixture01 shared    0.8718224
# 41 shared    shared    0.9912402
# 42 singleton shared    0.6337326
# 43 high_het  singleton 0.9268676
# 44 identity  singleton 0.9294301
# 45 low_het   singleton 0.9348478
# 46 mid_het   singleton 0.9363354
# 47 mixture01 singleton 0.9361214
# 48 shared    singleton 0.9310871
# 49 singleton singleton 0.9360988

# %% [markdown]
# ### Size of CS

# %%
aggregate(size~pattern+method, res, median)
# Out:
#    pattern   method    size
# 1  high_het  high_het  2.25
# 2  identity  high_het  3.00
# 3  low_het   high_het  2.00
# 4  mid_het   high_het  3.00
# 5  mixture01 high_het  4.00
# 6  shared    high_het  2.50
# 7  singleton high_het  6.25
# 8  high_het  identity  2.25
# 9  identity  identity  3.00
# 10 low_het   identity  2.00
# 11 mid_het   identity  3.00
# 12 mixture01 identity  4.00
# 13 shared    identity  2.50
# 14 singleton identity  6.75
# 15 high_het  low_het   2.50
# 16 identity  low_het   3.00
# 17 low_het   low_het   2.00
# 18 mid_het   low_het   3.00
# 19 mixture01 low_het   4.00
# 20 shared    low_het   2.50
# 21 singleton low_het   6.00
# 22 high_het  mid_het   2.25
# 23 identity  mid_het   3.00
# 24 low_het   mid_het   2.00
# 25 mid_het   mid_het   3.00
# 26 mixture01 mid_het   4.00
# 27 shared    mid_het   2.50
# 28 singleton mid_het   6.25
# 29 high_het  mixture_1 2.25
# 30 identity  mixture_1 3.00
# 31 low_het   mixture_1 2.00
# 32 mid_het   mixture_1 3.00
# 33 mixture01 mixture_1 4.00
# 34 shared    mixture_1 2.00
# 35 singleton mixture_1 8.00
# 36 high_het  shared    4.00
# 37 identity  shared    5.00
# 38 low_het   shared    3.00
# 39 mid_het   shared    4.00
# 40 mixture01 shared    3.75
# 41 shared    shared    2.50
# 42 singleton shared    2.25
# 43 high_het  singleton 8.00
# 44 identity  singleton 9.00
# 45 low_het   singleton 6.50
# 46 mid_het   singleton 9.00
# 47 mixture01 singleton 8.00
# 48 shared    singleton 8.25
# 49 singleton singleton 8.00

# %% [markdown]
# ### Power

# %%
valid = aggregate(valid ~ pattern + method, res, sum)
total_true = aggregate(total_true ~ pattern + method, res, sum)
overlap = aggregate(overlap ~ pattern + method, res, mean)
power = merge(valid, total_true, by = c("pattern", "method"))
power = merge(power, overlap,  by = c("pattern", "method"))
power$power = power$valid/power$total_true
power
# Out:
#    pattern   method    valid total_true overlap      power
# 1  high_het  high_het  238   250          7.04000000 0.9520000
# 2  high_het  identity  240   250          6.88000000 0.9600000
# 3  high_het  low_het   241   250          3.12666667 0.9640000
# 4  high_het  mid_het   241   250          2.65333333 0.9640000
# 5  high_het  mixture_1 235   250          0.00000000 0.9400000
# 6  high_het  shared    264   250         60.69333333 1.0560000
# 7  high_het  singleton 683   250        209.06000000 2.7320000
# 8  identity  high_het  254   266          0.19333333 0.9548872
# 9  identity  identity  255   266          0.19333333 0.9586466
# 10 identity  low_het   255   266          0.36666667 0.9586466
# 11 identity  mid_het   254   266          0.20000000 0.9548872
# 12 identity  mixture_1 249   266          0.00000000 0.9360902
# 13 identity  shared    276   266         67.72000000 1.0375940
# 14 identity  singleton 750   266        224.22000000 2.8195489
# 15 low_het   high_het  230   255          0.00000000 0.9019608
# 16 low_het   identity  230   255          0.00000000 0.9019608
# 17 low_het   low_het   230   255          0.00000000 0.9019608
# 18 low_het   mid_het   230   255          0.00000000 0.9019608
# 19 low_het   mixture_1 228   255          0.00000000 0.8941176
# 20 low_het   shared    243   255          3.94666667 0.9529412
# 21 low_het   singleton 660   255        129.87333333 2.5882353
# 22 mid_het   high_het  239   251          0.00000000 0.9521912
# 23 mid_het   identity  239   251          0.00000000 0.9521912
# 24 mid_het   low_het   242   251          0.06000000 0.9641434
# 25 mid_het   mid_het   241   251          0.00000000 0.9601594
# 26 mid_het   mixture_1 234   251          0.00000000 0.9322709
# 27 mid_het   shared    264   251          4.24000000 1.0517928
# 28 mid_het   singleton 718   251        186.18666667 2.8605578
# 29 mixture01 high_het  231   254          0.02666667 0.9094488
# 30 mixture01 identity  231   254          0.02666667 0.9094488
# 31 mixture01 low_het   224   254          0.36666667 0.8818898
# 32 mixture01 mid_het   229   254          0.00000000 0.9015748
# 33 mixture01 mixture_1 226   254          0.00000000 0.8897638
# 34 mixture01 shared    205   254          4.13333333 0.8070866
# 35 mixture01 singleton 565   254        127.50666667 2.2244094
# 36 shared    high_het  245   263          0.00000000 0.9315589
# 37 shared    identity  244   263          0.00000000 0.9277567
# 38 shared    low_het   245   263          0.00000000 0.9315589
# 39 shared    mid_het   245   263          0.00000000 0.9315589
# 40 shared    mixture_1 245   263          0.00000000 0.9315589
# 41 shared    shared    243   263          0.00000000 0.9239544
# 42 shared    singleton 700   263        181.52000000 2.6615970
# 43 singleton high_het  185   241          0.00000000 0.7676349
# 44 singleton identity  190   241          0.00000000 0.7883817
# 45 singleton low_het   185   241          0.00000000 0.7676349
# 46 singleton mid_het   184   241          0.00000000 0.7634855
# 47 singleton mixture_1 190   241          0.00000000 0.7883817
# 48 singleton shared    108   241          0.00000000 0.4481328
# 49 singleton singleton 196   241          0.00000000 0.8132780

# %% [markdown]
# ### FDR

# %%
valid = aggregate(valid ~ pattern + method, res, sum)
total = aggregate(total ~ pattern + method, res, sum)
fdr = merge(valid, total, by = c("pattern", "method"))
fdr$fdr = (fdr$total - fdr$valid)/fdr$total
fdr
# Out:
#    pattern   method    valid total fdr
# 1  high_het  high_het  238   259   0.08108108
# 2  high_het  identity  240   260   0.07692308
# 3  high_het  low_het   241   257   0.06225681
# 4  high_het  mid_het   241   259   0.06949807
# 5  high_het  mixture_1 235   245   0.04081633
# 6  high_het  shared    264   267   0.01123596
# 7  high_het  singleton 683   726   0.05922865
# 8  identity  high_het  254   271   0.06273063
# 9  identity  identity  255   272   0.06250000
# 10 identity  low_het   255   269   0.05204461
# 11 identity  mid_het   254   269   0.05576208
# 12 identity  mixture_1 249   267   0.06741573
# 13 identity  shared    276   292   0.05479452
# 14 identity  singleton 750   806   0.06947891
# 15 low_het   high_het  230   254   0.09448819
# 16 low_het   identity  230   254   0.09448819
# 17 low_het   low_het   230   251   0.08366534
# 18 low_het   mid_het   230   253   0.09090909
# 19 low_het   mixture_1 228   246   0.07317073
# 20 low_het   shared    243   260   0.06538462
# 21 low_het   singleton 660   711   0.07172996
# 22 mid_het   high_het  239   257   0.07003891
# 23 mid_het   identity  239   256   0.06640625
# 24 mid_het   low_het   242   257   0.05836576
# 25 mid_het   mid_het   241   256   0.05859375
# 26 mid_het   mixture_1 234   251   0.06772908
# 27 mid_het   shared    264   277   0.04693141
# 28 mid_het   singleton 718   775   0.07354839
# 29 mixture01 high_het  231   252   0.08333333
# 30 mixture01 identity  231   252   0.08333333
# 31 mixture01 low_het   224   245   0.08571429
# 32 mixture01 mid_het   229   250   0.08400000
# 33 mixture01 mixture_1 226   241   0.06224066
# 34 mixture01 shared    205   217   0.05529954
# 35 mixture01 singleton 565   604   0.06456954
# 36 shared    high_het  245   269   0.08921933
# 37 shared    identity  244   269   0.09293680
# 38 shared    low_het   245   267   0.08239700
# 39 shared    mid_het   245   268   0.08582090
# 40 shared    mixture_1 245   261   0.06130268
# 41 shared    shared    243   267   0.08988764
# 42 shared    singleton 700   763   0.08256881
# 43 singleton high_het  185   211   0.12322275
# 44 singleton identity  190   214   0.11214953
# 45 singleton low_het   185   206   0.10194175
# 46 singleton mid_het   184   210   0.12380952
# 47 singleton mixture_1 190   201   0.05472637
# 48 singleton shared    108   116   0.06896552
# 49 singleton singleton 196   205   0.04390244

# %% [markdown]
# ### Top-hit rate (how often the strongest SNP is causal)

# %%
top_hit = aggregate(top_hit ~ pattern + method, res, sum)
total_true = aggregate(total_true ~ pattern + method, res, sum)
top_rate = merge(top_hit, total_true, by = c("pattern", "method"))
top_rate$top_rate = top_rate$top_hit/top_rate$total_true
top_rate
# Out:
#    pattern   method    top_hit total_true top_rate
# 1  high_het  high_het  174     300        0.58000000
# 2  high_het  identity  174     300        0.58000000
# 3  high_het  low_het   171     300        0.57000000
# 4  high_het  mid_het   172     300        0.57333333
# 5  high_het  mixture_1 164     300        0.54666667
# 6  high_het  shared     99     300        0.33000000
# 7  high_het  singleton 404     300        1.34666667
# 8  identity  high_het  174     300        0.58000000
# 9  identity  identity  174     300        0.58000000
# 10 identity  low_het   174     300        0.58000000
# 11 identity  mid_het   174     300        0.58000000
# 12 identity  mixture_1 167     300        0.55666667
# 13 identity  shared     71     300        0.23666667
# 14 identity  singleton 359     300        1.19666667
# 15 low_het   high_het  167     300        0.55666667
# 16 low_het   identity  166     300        0.55333333
# 17 low_het   low_het   167     300        0.55666667
# 18 low_het   mid_het   167     300        0.55666667
# 19 low_het   mixture_1 155     300        0.51666667
# 20 low_het   shared    109     300        0.36333333
# 21 low_het   singleton 380     300        1.26666667
# 22 mid_het   high_het  167     300        0.55666667
# 23 mid_het   identity  167     300        0.55666667
# 24 mid_het   low_het   169     300        0.56333333
# 25 mid_het   mid_het   167     300        0.55666667
# 26 mid_het   mixture_1 158     300        0.52666667
# 27 mid_het   shared     97     300        0.32333333
# 28 mid_het   singleton 456     300        1.52000000
# 29 mixture01 high_het  144     300        0.48000000
# 30 mixture01 identity  144     300        0.48000000
# 31 mixture01 low_het   145     300        0.48333333
# 32 mixture01 mid_het   143     300        0.47666667
# 33 mixture01 mixture_1 144     300        0.48000000
# 34 mixture01 shared    107     300        0.35666667
# 35 mixture01 singleton 342     300        1.14000000
# 36 shared    high_het  158     300        0.52666667
# 37 shared    identity  158     300        0.52666667
# 38 shared    low_het   159     300        0.53000000
# 39 shared    mid_het   158     300        0.52666667
# 40 shared    mixture_1 159     300        0.53000000
# 41 shared    shared    158     300        0.52666667
# 42 shared    singleton 382     300        1.27333333
# 43 singleton high_het   94     300        0.31333333
# 44 singleton identity   93     300        0.31000000
# 45 singleton low_het    93     300        0.31000000
# 46 singleton mid_het    93     300        0.31000000
# 47 singleton mixture_1  85     300        0.28333333
# 48 singleton shared      8     300        0.02666667
# 49 singleton singleton  87     300        0.29000000

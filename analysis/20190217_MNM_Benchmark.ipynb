# %% [markdown]
# # M&M ASH benchmark V
#
# This is a continuation of Part V where I set total PVE is set to 0.15 and assume 2 causal variables per region. But here, the two SNPs have the same effects sampled from the multivariate distribution. Also I use $R = 5$ conditions and run it on $J=1000$ and 150 genes.
#
# The most important difference from previous simulations is that here I mix-match simulated data under different prior assumptions to analyzing them with different priors. I expect to observe that:
#
# 1. The "oracle" prior is always better than using other priors, for all scenarios.
# 2. Mixture prior generally performs well in all scenarios -- it is robust to simulation assumptions.

# %% [markdown]
# ## Conclusion
#
# ...

# %% [markdown]
# The benchmark was executd on UChicago midway
#
# ```
# ./finemap.dsc --host mnm_R5.yml --R 5
# ```
#
# This executes the `default` pipeline in `finemap.dsc` file, as of today (2019.02.04).

# %%
%cd ~/GIT/github/mnm-twas/dsc
# Out:
# /scratch/midway2/gaow/GIT/github/mnm-twas/dsc

# %%
start_time <- Sys.time()
library('dscrutils')
out = dscquery('finemap_output', "sharing_pattern mnm.eff_mode susie_scores.total susie_scores.valid susie_scores.size susie_scores.purity susie_scores.top susie_scores.n_causal susie_scores.included_causal susie_scores.overlap", omit.file.columns = T, verbose = F)
end_time <- Sys.time()

# %%
saveRDS(out, 'finemap_output/benchmark_v.rds')

# %%
# out = readRDS('finemap_output/benchmark_v.rds')

# %%
end_time - start_time
# Out:
# Time difference of 2.014167 mins

# %%
head(out)
# Out:
#   DSC sharing_pattern mnm          mnm.eff_mode susie_scores.total
# 1 1   identity        mnm_identity identity     1
# 2 1   identity        mnm_identity identity     2
# 3 1   identity        mnm_identity identity     1
# 4 1   identity        mnm_identity identity     1
# 5 1   identity        mnm_identity identity     1
# 6 1   identity        mnm_identity identity     3
#   susie_scores.valid susie_scores.size susie_scores.purity susie_scores.top
# 1 1                   1.0              1.0000000           1
# 2 2                   3.5              0.9813743           1
# 3 1                   2.0              1.0000000           1
# 4 1                   6.0              1.0000000           0
# 5 1                  17.0              0.9615369           0
# 6 2                   3.0              0.9806151           1
#   susie_scores.n_causal susie_scores.included_causal susie_scores.overlap
# 1 1                     1                            0
# 2 2                     2                            0
# 3 1                     1                            0
# 4 1                     1                            0
# 5 1                     1                            0
# 6 2                     2                            0

# %%
res = out[,c(2,4,5,6,7,8,9,10,11,12)]
colnames(res) = c('pattern', 'method', 'total', 'valid', 'size', 'purity', 'top_hit', 'total_true', 'total_true_included', 'overlap')

# %% [markdown]
# ### Purity of CS

# %%
aggregate(purity~pattern + method, res, mean)
# Out:
#    pattern   method    purity
# 1  high_het  high_het  0.9861015
# 2  identity  high_het  0.9872195
# 3  low_het   high_het  0.9836635
# 4  mid_het   high_het  0.9868067
# 5  mixture01 high_het  0.9534270
# 6  shared    high_het  0.9825523
# 7  singleton high_het  0.8427970
# 8  high_het  identity  0.9847402
# 9  identity  identity  0.9870663
# 10 low_het   identity  0.9827262
# 11 mid_het   identity  0.9870603
# 12 mixture01 identity  0.9498540
# 13 shared    identity  0.9835191
# 14 singleton identity  0.8427763
# 15 high_het  low_het   0.9854991
# 16 identity  low_het   0.9866075
# 17 low_het   low_het   0.9833000
# 18 mid_het   low_het   0.9859065
# 19 mixture01 low_het   0.9474465
# 20 shared    low_het   0.9844297
# 21 singleton low_het   0.8326556
# 22 high_het  mid_het   0.9864478
# 23 identity  mid_het   0.9868500
# 24 low_het   mid_het   0.9840402
# 25 mid_het   mid_het   0.9864577
# 26 mixture01 mid_het   0.9526083
# 27 shared    mid_het   0.9823964
# 28 singleton mid_het   0.8327097
# 29 high_het  mixture_1 0.9833868
# 30 identity  mixture_1 0.9875281
# 31 low_het   mixture_1 0.9854068
# 32 mid_het   mixture_1 0.9862468
# 33 mixture01 mixture_1 0.9550036
# 34 shared    mixture_1 0.9848500
# 35 singleton mixture_1 0.8470917
# 36 high_het  shared    0.8397760
# 37 identity  shared    0.8470565
# 38 low_het   shared    0.9676177
# 39 mid_het   shared    0.9261310
# 40 mixture01 shared    0.8227725
# 41 shared    shared    0.9839748
# 42 singleton shared    0.4069221
# 43 high_het  singleton 0.8932618
# 44 identity  singleton 0.8987961
# 45 low_het   singleton 0.8890945
# 46 mid_het   singleton 0.8896349
# 47 mixture01 singleton 0.8861702
# 48 shared    singleton 0.8907897
# 49 singleton singleton 0.8560818

# %% [markdown]
# ### Size of CS

# %%
aggregate(size~pattern+method, res, median)
# Out:
#    pattern   method    size
# 1  high_het  high_het   3.50
# 2  identity  high_het   3.00
# 3  low_het   high_het   4.00
# 4  mid_het   high_het   3.00
# 5  mixture01 high_het   4.50
# 6  shared    high_het   4.00
# 7  singleton high_het   9.00
# 8  high_het  identity   3.50
# 9  identity  identity   3.00
# 10 low_het   identity   4.00
# 11 mid_het   identity   3.00
# 12 mixture01 identity   4.25
# 13 shared    identity   4.00
# 14 singleton identity   8.50
# 15 high_het  low_het    3.50
# 16 identity  low_het    3.00
# 17 low_het   low_het    4.00
# 18 mid_het   low_het    3.00
# 19 mixture01 low_het    4.25
# 20 shared    low_het    4.00
# 21 singleton low_het    9.00
# 22 high_het  mid_het    3.25
# 23 identity  mid_het    3.25
# 24 low_het   mid_het    4.00
# 25 mid_het   mid_het    3.00
# 26 mixture01 mid_het    4.75
# 27 shared    mid_het    4.00
# 28 singleton mid_het    9.00
# 29 high_het  mixture_1  3.50
# 30 identity  mixture_1  3.00
# 31 low_het   mixture_1  4.00
# 32 mid_het   mixture_1  3.00
# 33 mixture01 mixture_1  4.25
# 34 shared    mixture_1  4.00
# 35 singleton mixture_1  9.00
# 36 high_het  shared     4.75
# 37 identity  shared     4.00
# 38 low_het   shared     5.00
# 39 mid_het   shared     4.00
# 40 mixture01 shared     3.25
# 41 shared    shared     4.00
# 42 singleton shared     0.00
# 43 high_het  singleton 11.00
# 44 identity  singleton  9.25
# 45 low_het   singleton 12.50
# 46 mid_het   singleton  9.50
# 47 mixture01 singleton 12.25
# 48 shared    singleton 11.00
# 49 singleton singleton  9.00

# %% [markdown]
# ### Power

# %%
total_true_included = aggregate(total_true_included ~ pattern + method, res, sum)
total_true = aggregate(total_true ~ pattern + method, res, sum)
overlap = aggregate(overlap ~ pattern + method, res, mean)
power = merge(total_true_included, total_true, by = c("pattern", "method"))
power = merge(power, overlap,  by = c("pattern", "method"))
power$power = power$total_true_included/power$total_true
power
# Out:
#    pattern   method    total_true_included total_true overlap     power
# 1  high_het  high_het  249                 272          1.4600000 0.9154412
# 2  high_het  identity  250                 272          1.4933333 0.9191176
# 3  high_het  low_het   248                 272          0.0000000 0.9117647
# 4  high_het  mid_het   249                 272          1.4733333 0.9154412
# 5  high_het  mixture_1 241                 272          0.0000000 0.8860294
# 6  high_het  shared    206                 272          9.4000000 0.7573529
# 7  high_het  singleton 235                 272        209.5333333 0.8639706
# 8  identity  high_het  228                 244          0.0000000 0.9344262
# 9  identity  identity  228                 244          0.0000000 0.9344262
# 10 identity  low_het   226                 244          0.0000000 0.9262295
# 11 identity  mid_het   227                 244          0.0000000 0.9303279
# 12 identity  mixture_1 224                 244          0.0000000 0.9180328
# 13 identity  shared    182                 244          3.7866667 0.7459016
# 14 identity  singleton 217                 244        133.8800000 0.8893443
# 15 low_het   high_het  238                 267          0.0000000 0.8913858
# 16 low_het   identity  240                 267          0.0000000 0.8988764
# 17 low_het   low_het   242                 267          0.0000000 0.9063670
# 18 low_het   mid_het   238                 267          0.0000000 0.8913858
# 19 low_het   mixture_1 234                 267          0.0000000 0.8764045
# 20 low_het   shared    238                 267          1.5800000 0.8913858
# 21 low_het   singleton 231                 267        131.7533333 0.8651685
# 22 mid_het   high_het  225                 253          0.0000000 0.8893281
# 23 mid_het   identity  227                 253          0.0000000 0.8972332
# 24 mid_het   low_het   225                 253          0.0000000 0.8893281
# 25 mid_het   mid_het   225                 253          0.0000000 0.8893281
# 26 mid_het   mixture_1 225                 253          0.0000000 0.8893281
# 27 mid_het   shared    207                 253          1.6466667 0.8181818
# 28 mid_het   singleton 205                 253        152.2266667 0.8102767
# 29 mixture01 high_het  216                 257          0.0000000 0.8404669
# 30 mixture01 identity  216                 257          0.0000000 0.8404669
# 31 mixture01 low_het   212                 257          0.0000000 0.8249027
# 32 mixture01 mid_het   216                 257          0.0000000 0.8404669
# 33 mixture01 mixture_1 219                 257          0.0000000 0.8521401
# 34 mixture01 shared    189                 257          8.7533333 0.7354086
# 35 mixture01 singleton 209                 257        166.0466667 0.8132296
# 36 shared    high_het  248                 270          0.3400000 0.9185185
# 37 shared    identity  245                 270          0.0000000 0.9074074
# 38 shared    low_het   251                 270          4.7733333 0.9296296
# 39 shared    mid_het   251                 270          4.8066667 0.9296296
# 40 shared    mixture_1 248                 270          0.3466667 0.9185185
# 41 shared    shared    254                 270          4.7400000 0.9407407
# 42 shared    singleton 227                 270        212.4066667 0.8407407
# 43 singleton high_het  166                 244          0.0000000 0.6803279
# 44 singleton identity  167                 244          0.0000000 0.6844262
# 45 singleton low_het   158                 244          0.0000000 0.6475410
# 46 singleton mid_het   162                 244          0.0000000 0.6639344
# 47 singleton mixture_1 159                 244          0.0000000 0.6516393
# 48 singleton shared     71                 244          0.0000000 0.2909836
# 49 singleton singleton 162                 244          0.0000000 0.6639344

# %% [markdown]
# ### FDR

# %%
valid = aggregate(valid ~ pattern + method, res, sum)
total = aggregate(total ~ pattern + method, res, sum)
fdr = merge(valid, total, by = c("pattern", "method"))
fdr$fdr = (fdr$total - fdr$valid)/fdr$total
fdr
# Out:
#    pattern   method    valid total fdr
# 1  high_het  high_het  250   270   0.07407407
# 2  high_het  identity  251   271   0.07380074
# 3  high_het  low_het   248   265   0.06415094
# 4  high_het  mid_het   250   268   0.06716418
# 5  high_het  mixture_1 240   258   0.06976744
# 6  high_het  shared    220   227   0.03083700
# 7  high_het  singleton 616   668   0.07784431
# 8  identity  high_het  227   242   0.06198347
# 9  identity  identity  227   242   0.06198347
# 10 identity  low_het   225   239   0.05857741
# 11 identity  mid_het   226   240   0.05833333
# 12 identity  mixture_1 223   231   0.03463203
# 13 identity  shared    202   208   0.02884615
# 14 identity  singleton 574   604   0.04966887
# 15 low_het   high_het  238   268   0.11194030
# 16 low_het   identity  239   269   0.11152416
# 17 low_het   low_het   242   266   0.09022556
# 18 low_het   mid_het   238   267   0.10861423
# 19 low_het   mixture_1 234   254   0.07874016
# 20 low_het   shared    247   264   0.06439394
# 21 low_het   singleton 607   666   0.08858859
# 22 mid_het   high_het  223   246   0.09349593
# 23 mid_het   identity  225   245   0.08163265
# 24 mid_het   low_het   223   245   0.08979592
# 25 mid_het   mid_het   223   246   0.09349593
# 26 mid_het   mixture_1 223   238   0.06302521
# 27 mid_het   shared    226   234   0.03418803
# 28 mid_het   singleton 572   611   0.06382979
# 29 mixture01 high_het  212   235   0.09787234
# 30 mixture01 identity  212   234   0.09401709
# 31 mixture01 low_het   209   233   0.10300429
# 32 mixture01 mid_het   212   235   0.09787234
# 33 mixture01 mixture_1 215   230   0.06521739
# 34 mixture01 shared    196   211   0.07109005
# 35 mixture01 singleton 511   564   0.09397163
# 36 shared    high_het  247   270   0.08518519
# 37 shared    identity  243   269   0.09665428
# 38 shared    low_het   251   268   0.06343284
# 39 shared    mid_het   251   272   0.07720588
# 40 shared    mixture_1 247   264   0.06439394
# 41 shared    shared    254   269   0.05576208
# 42 shared    singleton 622   669   0.07025411
# 43 singleton high_het  164   183   0.10382514
# 44 singleton identity  165   184   0.10326087
# 45 singleton low_het   156   170   0.08235294
# 46 singleton mid_het   160   176   0.09090909
# 47 singleton mixture_1 157   167   0.05988024
# 48 singleton shared     70    72   0.02777778
# 49 singleton singleton 160   170   0.05882353

# %% [markdown]
# ### Top-hit rate (how often the strongest SNP is causal)

# %%
top_hit = aggregate(top_hit ~ pattern + method, res, sum)
total_true = aggregate(total_true ~ pattern + method, res, sum)
top_rate = merge(top_hit, total_true, by = c("pattern", "method"))
top_rate$top_rate = top_rate$top_hit/top_rate$total_true
top_rate
# Out:
#    pattern   method    top_hit total_true top_rate
# 1  high_het  high_het  139     272        0.51102941
# 2  high_het  identity  138     272        0.50735294
# 3  high_het  low_het   138     272        0.50735294
# 4  high_het  mid_het   140     272        0.51470588
# 5  high_het  mixture_1 129     272        0.47426471
# 6  high_het  shared    112     272        0.41176471
# 7  high_het  singleton 262     272        0.96323529
# 8  identity  high_het  135     244        0.55327869
# 9  identity  identity  135     244        0.55327869
# 10 identity  low_het   135     244        0.55327869
# 11 identity  mid_het   135     244        0.55327869
# 12 identity  mixture_1 133     244        0.54508197
# 13 identity  shared    105     244        0.43032787
# 14 identity  singleton 260     244        1.06557377
# 15 low_het   high_het  135     267        0.50561798
# 16 low_het   identity  134     267        0.50187266
# 17 low_het   low_het   133     267        0.49812734
# 18 low_het   mid_het   135     267        0.50561798
# 19 low_het   mixture_1 128     267        0.47940075
# 20 low_het   shared    129     267        0.48314607
# 21 low_het   singleton 248     267        0.92883895
# 22 mid_het   high_het  138     253        0.54545455
# 23 mid_het   identity  139     253        0.54940711
# 24 mid_het   low_het   137     253        0.54150198
# 25 mid_het   mid_het   137     253        0.54150198
# 26 mid_het   mixture_1 139     253        0.54940711
# 27 mid_het   shared    131     253        0.51778656
# 28 mid_het   singleton 284     253        1.12252964
# 29 mixture01 high_het  115     257        0.44747082
# 30 mixture01 identity  115     257        0.44747082
# 31 mixture01 low_het   114     257        0.44357977
# 32 mixture01 mid_het   115     257        0.44747082
# 33 mixture01 mixture_1 117     257        0.45525292
# 34 mixture01 shared    107     257        0.41634241
# 35 mixture01 singleton 221     257        0.85992218
# 36 shared    high_het  137     270        0.50740741
# 37 shared    identity  134     270        0.49629630
# 38 shared    low_het   138     270        0.51111111
# 39 shared    mid_het   138     270        0.51111111
# 40 shared    mixture_1 134     270        0.49629630
# 41 shared    shared    136     270        0.50370370
# 42 shared    singleton 257     270        0.95185185
# 43 singleton high_het   61     244        0.25000000
# 44 singleton identity   63     244        0.25819672
# 45 singleton low_het    55     244        0.22540984
# 46 singleton mid_het    58     244        0.23770492
# 47 singleton mixture_1  61     244        0.25000000
# 48 singleton shared     20     244        0.08196721
# 49 singleton singleton  64     244        0.26229508
